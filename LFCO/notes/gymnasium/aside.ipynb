# %%
from libraries import *    
from gym.spaces import Discrete

# %%
FROZEN_LAKE_ENV = "FrozenLake-v0"

env = gym.make(FROZEN_LAKE_ENV)
env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %%
space: Discrete = env.observation_space
actions: Discrete = env.action_space
transition: dict[int, dict[int, list[tuple[int, int, float, bool], ..., ...]]] = env.P

'''
    {
        state_t_|16|: { 
            action_|4|: [(prob, state_tpp_|16|, reward, is_final)]
        }
    }
'''

print(f'{space, actions=}')
print(f'{transition=}')
# Out:
# space, actions=(Discrete(16), Discrete(4))
# ...

# %%
transition[14][2]
# Out:
# [(0.3333333333333333, 14, 0.0, False),
#  (0.3333333333333333, 15, 1.0, True),
#  (0.3333333333333333, 10, 0.0, False)]

# %%
env_space = env.reset()
print(f'{env_space=}')
env.render()
# Out:
# env_space=0
#
# SFFF
# FHFH
# FFFH
# HFFG

# %%
a = env.action_space.sample()
a
# Out:
# 3

# %%
s_, r, done, info = env.step(a)
print(f'{s_, r, done, info=}')
# Out:
# s_, r, done, info=(1, 0.0, False, {'prob': 0.3333333333333333})

# %%
env.render()
# Out:
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
