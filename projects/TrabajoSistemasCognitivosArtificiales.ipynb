# %% [markdown]
# 1. 50 % Realice el seguimiento del algoritmo de Anchura, Profundidad ,  Hill Climbing,   A estrella en el  siguiente grafo con los valores. Dónde se representa los posibles rutas para ir entre ciudades, en este caso el origen es A y el destino final L. La tabla es la heurística o distancia estimada para ir desde cualquier ciudad al destin
#
#
# [image](https://virtual.ucaldas.edu.co/pluginfile.php/392407/mod_page/content/3/Grafico.png)
